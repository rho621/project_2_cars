# %%
import pandas as pd

# %%
cars_csv = "cars_database.csv"

# %%
cars_data_df = pd.read_csv(cars_csv)
cars_data_df
# Out:
#            Make                             Model    Type  Origin DriveTrain  \
# 0         Acura                               MDX     SUV    Asia        All
# 1         Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 2         Acura                           TSX 4dr   Sedan    Asia      Front
# 3         Acura                            TL 4dr   Sedan    Asia      Front
# 4         Acura                        3.5 RL 4dr   Sedan    Asia      Front
# 5         Acura           3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6         Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 7          Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8          Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9          Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10         Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# ...

# %%
#check unique value of make to compare with the other json file. 


make = cars_data_df['Make']
make.value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Volkswagen       15
# Chrysler         15
# Mitsubishi       13
# Dodge            13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Lexus            11
# Subaru           11
# Mazda            11
# Pontiac          11
# Kia              11
# Mercury           9
# Buick             9
# Lincoln           9
# Saturn            8
# GMC               8
# Suzuki            8
# Infiniti          8
# Cadillac          8
# Acura             7
# Porsche           7
# Saab              7
# Oldsmobile        3
# Land Rover        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
#choose columns of interest, Use make and model as the primary key. 

new_car_data = cars_data_df[['Make','Model','Origin','MSRP','Weight','MPG_Highway' ]]
new_car_data.head()
# Out:
#     Make           Model Origin     MSRP  Weight  MPG_Highway
# 0  Acura             MDX   Asia  $36,945    4451           23
# 1  Acura  RSX Type S 2dr   Asia  $23,820    2778           31
# 2  Acura         TSX 4dr   Asia  $26,990    3230           29
# 3  Acura          TL 4dr   Asia  $33,195    3575           28
# 4  Acura      3.5 RL 4dr   Asia  $43,755    3880           24

# %%
#Modify model, try to get only the model name. 

model = new_car_data["Model"]

modified_model=[]


split = model.str.split()


for name in split:
    print(split[0])
# Out:
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ['MDX']
# ...

# %%
json_file = "car_database.json"
customer_location_df = pd.read_json(json_file, lines=True)
customer_location_df
# Out:
#       100 km/h - 0 200 km/h - 0  ABS Acceleration 0 - 100 km/h  \
# 0              NaN          NaN  yes                   6.9 sec
# 1              NaN          NaN  yes                   6.8 sec
# 2              NaN          NaN  yes                   7.4 sec
# 3              NaN          NaN  yes                   7.3 sec
# 4              NaN          NaN  yes                   6.9 sec
# 5              NaN          NaN  yes                   6.7 sec
# 6              NaN          NaN  yes                     8 sec
# 7              NaN          NaN  yes                   7.8 sec
# 8              NaN          NaN  yes                   7.4 sec
# 9              NaN          NaN  yes                   7.3 sec
# 10             NaN          NaN  yes                   6.9 sec
# 11             NaN          NaN  yes                   6.7 sec
# 12             NaN          NaN  yes                     8 sec
# 13             NaN          NaN  yes                   7.8 sec
# ...
